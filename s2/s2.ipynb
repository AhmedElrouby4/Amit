# %%
list_one = [1, 2, 3, 4, "amit", "learning", True, [1, 2, 3, 4, ["cv", "nlp"]]]

# %%
list_one.append("HELLO")
list_one
# Out:
# [1, 2, 3, 4, 'amit', 'learning', True, [1, 2, 3, 4, ['cv', 'nlp']], 'HELLO']

# %%
x = input("plz enter ur name")
y = input("plz enter ur id")
print(x+y)
# Out:
# Ahmed2005

# %%
num1 = float(input("enter first number "))
num2 = float(input("enter second nimber "))
print(f"sum ")
