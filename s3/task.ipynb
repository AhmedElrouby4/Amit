# %%
# Task 1

email = "Amit_ml@gmail.edu"

valid = email.count('@') == 1 and '.' in email.split('@')[1]

print("Task 1 Result:")
print("Valid Email:", valid)

username = email.split('@')[0]
print("Username:", username)

domain = email.split('@')[1].split('.')[-2]
print("Domain:", domain)

ending = email.split('.')[-1]
print("Domain Type:", ending)

# Task 2:

msg2 = "###!!@mocleW EPGTQ!!!6789"

core2 = ""
for c in msg2:
    if c.isalpha() or c == ' ':
        core2 += c

word1, word2 = core2.split()
word1 = word1[::-1]

print("\nTask 2 Result:")
print(word1, word2)

# Task 3

msg3 = "&&&**$gnirtS PLIO!!@1234"

core3 = ""
for c in msg3:
    if c.isalpha() or c == ' ':
        core3 += c

w1, w2 = core3.split()
w1 = w1[::-1]
w2 = w2.replace('I', 'E').replace('O', 'U')

print("\nTask 3 Result:")
print(w1, w2)

# Task 4:

msg4 = "##$$$@!yalpstcejorp EPUVT****9887"

core4 = ""
for c in msg4:
    if c.isalpha() or c == ' ':
        core4 += c

x1, x2 = core4.split()
x1 = x1[::-1]
x2 = x2.replace('E', 'A').replace('U', 'O')

print("\nTask 4 Result:")
print(x1, x2)
# Out:
# Task 1 Result:
# Valid Email: True
# Username: Amit_ml
# Domain: gmail
# Domain Type: edu
#
# Task 2 Result:
# Welcom EPGTQ
#
# Task 3 Result:
# String PLEU
#
# Task 4 Result:
# projectsplay APOVT
